# %%
import matplotlib.pyplot as plot
import csv
import numpy as np

# %%
average_ram_source_streaming = []
average_cpu_source_streaming = []
average_bandwidth_transmit_source_streaming = []
average_bandwidth_reiceive_source_streaming = []
average_time_source_streaming = []

average_ram_face_detection = []
average_cpu_face_detection = []
average_bandwidth_transmit_face_detection = []
average_bandwidth_reiceive_face_detection = []
average_time_face_detection = []

average_ram_background_blur = []
average_cpu_background_blur = []
average_bandwidth_transmit_background_blur = []
average_bandwidth_reiceive_background_blur = []
average_time_background_blur = []

average_ram_face_recognition = []
average_cpu_face_recognition = []
average_bandwidth_transmit_face_recognition = []
average_bandwidth_reiceive_face_recognition = []
average_time_face_recognition = []

average_ram_transcoder = []
average_cpu_transcoder = []
average_bandwidth_transmit_transcoder = []
average_bandwidth_reiceive_transcoder = []
average_time_transcoder = []

average_ram_match_av = []
average_cpu_match_av = []
average_bandwidth_transmit_match_av = []
average_bandwidth_reiceive_match_av = []
average_time_match_av = []

average_ram_noise_reduction = []
average_cpu_noise_reduction = []
average_bandwidth_transmit_noise_reduction = []
average_bandwidth_reiceive_noise_reduction = []
average_time_noise_reduction = []

# %%
for i in range(0,1):
    file_name = "data_prom_sfc_5_480_repeat_time_{}.csv".format(i)
    
    ram_face_recognition = []
    cpu_face_recognition = []
    bandwidth_face_recognition = []

    with open(file_name, newline='') as csvfile:
        spamreader = csv.reader(csvfile, delimiter=',', quotechar='|')
        for row in spamreader:
            if "face-recognition" in row[5]:
                cpu_face_recognition.append(float(row[1]))
                ram_face_recognition.append(float(row[2])/10**6)
        
        average_cpu_face_recognition.append(np.mean(cpu_face_recognition))
        average_ram_face_recognition.append(np.mean(ram_face_recognition))

ram_face_recognition_mean = np.mean(average_ram_face_recognition)
cpu_face_recognition_mean = np.mean(average_cpu_face_recognition)

ram_face_recognition_std = np.std(average_ram_face_recognition)
cpu_face_recognition_std = np.std(average_cpu_face_recognition)

# %%
for i in range(0,1):
    file_name = "data_prom_sfc_2_480_repeat_time_{}.csv".format(i)
    
    ram_background_blur = []
    cpu_background_blur = []
    bandwidth_background_blur = []

    with open(file_name, newline='') as csvfile:
        spamreader = csv.reader(csvfile, delimiter=',', quotechar='|')
        for row in spamreader:
            if "background-blur" in row[5]:
                cpu_background_blur.append(float(row[1]))
                ram_background_blur.append(float(row[2])/10**6)
        
        average_cpu_background_blur.append(np.mean(cpu_background_blur))
        average_ram_background_blur.append(np.mean(ram_background_blur))

ram_background_blur_mean = np.mean(average_ram_background_blur)
cpu_background_blur_mean = np.mean(average_cpu_background_blur)

ram_background_blur_std = np.std(average_ram_background_blur)
cpu_background_blur_std = np.std(average_cpu_background_blur)

# %%
for i in range(0,1):
    file_name = "data_prom_sfc_3_480_repeat_time_{}.csv".format(i)
    
    ram_face_detection = []
    cpu_face_detection = []
    bandwidth_face_detection = []

    with open(file_name, newline='') as csvfile:
        spamreader = csv.reader(csvfile, delimiter=',', quotechar='|')
        for row in spamreader:
            if "face-detection" in row[5]:
                cpu_face_detection.append(float(row[1]))
                ram_face_detection.append(float(row[2])/10**6)
        
        average_cpu_face_detection.append(np.mean(cpu_face_detection))
        average_ram_face_detection.append(np.mean(ram_face_detection))

ram_face_detection_mean = np.mean(average_ram_face_detection)
cpu_face_detection_mean = np.mean(average_cpu_face_detection)

ram_face_detection_std = np.std(average_ram_face_detection)
cpu_face_detection_std = np.std(average_cpu_face_detection)

# %%
for i in range(0,1):
    file_name = "data_prom_sfc_4_480_repeat_time_{}.csv".format(i)
    
    ram_transcoder = []
    cpu_transcoder = []
    bandwidth_transcoder = []

    with open(file_name, newline='') as csvfile:
        spamreader = csv.reader(csvfile, delimiter=',', quotechar='|')
        for row in spamreader:
            if "transcoder" in row[5]:
                cpu_transcoder.append(float(row[1]))
                ram_transcoder.append(float(row[2])/10**6)
        
        average_cpu_transcoder.append(np.mean(cpu_transcoder))
        average_ram_transcoder.append(np.mean(ram_transcoder))

ram_transcoder_mean = np.mean(average_ram_transcoder)
cpu_transcoder_mean = np.mean(average_cpu_transcoder)

ram_transcoder_std = np.std(average_ram_transcoder)
cpu_transcoder_std = np.std(average_cpu_transcoder)

# %%
for i in range(0, 1):
    file_name = "data_prom_sfc_1_480_repeat_time_{}.csv".format(
        i)

    ram_match_av = []
    cpu_match_av = []
    bandwidth_match_av = []
    bandwidth_transmit_match_av = []
    bandwidth_reiceive_match_av = []
    time_match_av = []

    with open(file_name, newline='') as csvfile:
        spamreader = csv.reader(csvfile, delimiter=',', quotechar='|')
        for row in spamreader:
            if "match-av" in row[5]:
                cpu_match_av.append(float(row[1]))
                ram_match_av.append(float(row[2])/10**6)
                bandwidth_transmit_match_av.append(float(row[4]))
                bandwidth_reiceive_match_av.append(float(row[3]))
                time_match_av.append(float(row[0]))

        average_cpu_match_av.append(np.mean(cpu_match_av))
        average_ram_match_av.append(np.mean(ram_match_av))
        average_bandwidth_transmit_match_av.append(
            (bandwidth_transmit_match_av[-1]-bandwidth_transmit_match_av[0])/(time_match_av[-1]-time_match_av[0]))
        average_bandwidth_reiceive_match_av.append(
            (bandwidth_reiceive_match_av[-1]-bandwidth_reiceive_match_av[0])/(time_match_av[-1]-time_match_av[0]))


ram_match_av_mean=np.mean(average_ram_match_av)
cpu_match_av_mean=np.mean(average_cpu_match_av)
bandwidth_transmit_match_av_mean=np.mean(average_bandwidth_transmit_match_av)
bandwidth_reiceive_match_av_mean=np.mean(average_bandwidth_reiceive_match_av)

ram_match_av_std=np.std(average_ram_match_av)
cpu_match_av_std=np.std(average_cpu_match_av)
bandwidth_transmit_match_av_std=np.std(average_bandwidth_transmit_match_av)
bandwidth_reiceive_match_av_std=np.std(average_bandwidth_reiceive_match_av)

# %%
for i in range(0, 1):
    file_name = "data_prom_sfc_6_480_repeat_time_{}.csv".format(
        i)

    ram_noise_reduction = []
    cpu_noise_reduction = []
    bandwidth_noise_reduction = []
    bandwidth_transmit_noise_reduction = []
    bandwidth_reiceive_noise_reduction = []
    time_noise_reduction = []

    with open(file_name, newline='') as csvfile:
        spamreader = csv.reader(csvfile, delimiter=',', quotechar='|')
        for row in spamreader:
            if "noise-suppress" in row[5]:
                cpu_noise_reduction.append(float(row[1]))
                ram_noise_reduction.append(float(row[2])/10**6)
      
        average_cpu_noise_reduction.append(np.mean(cpu_noise_reduction))
        average_ram_noise_reduction.append(np.mean(ram_noise_reduction))

ram_noise_reduction_mean=np.mean(average_ram_noise_reduction)
cpu_noise_reduction_mean=np.mean(average_cpu_noise_reduction)

ram_noise_reduction_std=np.std(average_ram_noise_reduction)
cpu_noise_reduction_std=np.std(average_cpu_noise_reduction)

# %%
# CPU in cloud
data = [cpu_face_recognition_mean, cpu_transcoder_mean,
        cpu_match_av_mean, cpu_noise_reduction_mean, cpu_face_detection_mean, cpu_background_blur_mean]
error = [cpu_face_recognition_std, cpu_transcoder_std,
         cpu_match_av_std, cpu_noise_reduction_std, cpu_face_detection_std, cpu_background_blur_std]
state = ["face recognition", "transcoder", "match av",
         "noise filter", "face detection", "background blur"]
fig1, ax1 = plot.subplots()
x_pos = x_pos = np.arange(len(state))
ax1.bar(x_pos, data, yerr=error, align='center',
        alpha=0.9, ecolor='black', capsize=10)
ax1.set_title('CPU(480p) in cloud')
ax1.set_ylabel("%")
plot.xticks(rotation = 15)
ax1.set_xticks(x_pos)
ax1.set_xticklabels(state)
for i, v in enumerate(data):
    if v > 2:
        ax1.text(i, v/2-(v/2)*0.05, str(round(v,2)), ha='center')
    else:    
        ax1.text(i, v+0.5, str(round(v,2)), ha='center')
plot.show()

# %%
# RAM in cloud
data = [ram_face_recognition_mean, ram_transcoder_mean,
        ram_match_av_mean, ram_noise_reduction_mean, ram_face_detection_mean, ram_background_blur_mean]
error = [ram_face_recognition_std, ram_transcoder_std,
         ram_match_av_std, ram_noise_reduction_std, ram_face_detection_std, ram_background_blur_std]
state = ["face recognition", "transcoder", "match av",
         "noise filter", "face detection", "background blur"]
fig1, ax1 = plot.subplots()
x_pos = x_pos = np.arange(len(state))
ax1.bar(x_pos, data, yerr=error, align='center',
        alpha=0.9, ecolor='black', capsize=10)
ax1.set_title('RAM(480p) in cloud')
ax1.set_ylabel("MB")
plot.xticks(rotation = 15)
ax1.set_xticks(x_pos)
ax1.set_xticklabels(state)
for i, v in enumerate(data):
    if v > 100:
        ax1.text(i, v/2-(v/2)*0.05, str(round(v)), ha='center')
    else:    
        ax1.text(i, v+10, str(round(v)), ha='center')
plot.show()

# %%
average_ram_sfc_1 = []
average_cpu_sfc_1 = []
average_bandwidth_sfc_1 = []

average_ram_sfc_2 = []
average_cpu_sfc_2 = []
average_bandwidth_sfc_2 = []

average_ram_sfc_3 = []
average_cpu_sfc_3 = []
average_bandwidth_sfc_3 = []

average_ram_sfc_4 = []
average_cpu_sfc_4 = []
average_bandwidth_sfc_4 = []

average_ram_sfc_5 = []
average_cpu_sfc_5 = []
average_bandwidth_sfc_5 = []

average_ram_sfc_6 = []
average_cpu_sfc_6 = []
average_bandwidth_sfc_6 = []

# %%
for i in range(0,1):
    file_name = "data_prom_nodes_sfc_1_480_repeat_time_{}.csv".format(i)
    
    ram_sfc_1 = []
    cpu_sfc_1 = []
    bandwidth_sfc_1 = []

    with open(file_name, newline='') as csvfile:
        spamreader = csv.reader(csvfile, delimiter=',', quotechar='|')
        for row in spamreader:
            if "node2" in row[5]:
                cpu_sfc_1.append(float(row[1]))
                ram_sfc_1.append(float(row[2]))
        
        average_cpu_sfc_1.append(np.mean(cpu_sfc_1))
        average_ram_sfc_1.append(np.mean(ram_sfc_1))

ram_sfc_1_mean = np.mean(average_ram_sfc_1)
cpu_sfc_1_mean = np.mean(average_cpu_sfc_1)

ram_sfc_1_std = np.std(average_ram_sfc_1)
cpu_sfc_1_std = np.std(average_cpu_sfc_1)

# %%
for i in range(0,1):
    file_name = "data_prom_nodes_sfc_2_480_repeat_time_{}.csv".format(i)
    
    ram_sfc_2 = []
    cpu_sfc_2 = []
    bandwidth_sfc_2 = []

    with open(file_name, newline='') as csvfile:
        spamreader = csv.reader(csvfile, delimiter=',', quotechar='|')
        for row in spamreader:
            if "node2" in row[5]:
                cpu_sfc_2.append(float(row[1]))
                ram_sfc_2.append(float(row[2]))
        
        average_cpu_sfc_2.append(np.mean(cpu_sfc_2))
        average_ram_sfc_2.append(np.mean(ram_sfc_2))

ram_sfc_2_mean = np.mean(average_ram_sfc_2)
cpu_sfc_2_mean = np.mean(average_cpu_sfc_2)

ram_sfc_2_std = np.std(average_ram_sfc_2)
cpu_sfc_2_std = np.std(average_cpu_sfc_2)

# %%
for i in range(0,1):
    file_name = "data_prom_nodes_sfc_3_480_repeat_time_{}.csv".format(i)
    
    ram_sfc_3 = []
    cpu_sfc_3 = []
    bandwidth_sfc_1 = []

    with open(file_name, newline='') as csvfile:
        spamreader = csv.reader(csvfile, delimiter=',', quotechar='|')
        for row in spamreader:
            if "node2" in row[5]:
                cpu_sfc_3.append(float(row[1]))
                ram_sfc_3.append(float(row[2]))
        
        average_cpu_sfc_3.append(np.mean(cpu_sfc_3))
        average_ram_sfc_3.append(np.mean(ram_sfc_3))

ram_sfc_3_mean = np.mean(average_ram_sfc_3)
cpu_sfc_3_mean = np.mean(average_cpu_sfc_3)

ram_sfc_3_std = np.std(average_ram_sfc_3)
cpu_sfc_3_std = np.std(average_cpu_sfc_3)

# %%
for i in range(0,1):
    file_name = "data_prom_nodes_sfc_4_480_repeat_time_{}.csv".format(i)
    
    ram_sfc_4 = []
    cpu_sfc_4 = []
    bandwidth_sfc_4 = []

    with open(file_name, newline='') as csvfile:
        spamreader = csv.reader(csvfile, delimiter=',', quotechar='|')
        for row in spamreader:
            if "node2" in row[5]:
                cpu_sfc_4.append(float(row[1]))
                ram_sfc_4.append(float(row[2]))
        
        average_cpu_sfc_4.append(np.mean(cpu_sfc_4))
        average_ram_sfc_4.append(np.mean(ram_sfc_4))

ram_sfc_4_mean = np.mean(average_ram_sfc_4)
cpu_sfc_4_mean = np.mean(average_cpu_sfc_4)

ram_sfc_4_std = np.std(average_ram_sfc_4)
cpu_sfc_4_std = np.std(average_cpu_sfc_4)

# %%
for i in range(0,1):
    file_name = "data_prom_nodes_sfc_5_480_repeat_time_{}.csv".format(i)
    
    ram_sfc_5 = []
    cpu_sfc_5 = []
    bandwidth_sfc_5 = []

    with open(file_name, newline='') as csvfile:
        spamreader = csv.reader(csvfile, delimiter=',', quotechar='|')
        for row in spamreader:
            if "node2" in row[5]:
                cpu_sfc_5.append(float(row[1]))
                ram_sfc_5.append(float(row[2]))
        
        average_cpu_sfc_5.append(np.mean(cpu_sfc_5))
        average_ram_sfc_5.append(np.mean(ram_sfc_5))

ram_sfc_5_mean = np.mean(average_ram_sfc_5)
cpu_sfc_5_mean = np.mean(average_cpu_sfc_5)

ram_sfc_5_std = np.std(average_ram_sfc_5)
cpu_sfc_5_std = np.std(average_cpu_sfc_5)
print(ram_sfc_5_mean)
# Out:
# 10.015368078613283

# %%
for i in range(0,1):
    file_name = "data_prom_nodes_sfc_6_480_repeat_time_{}.csv".format(i)
    
    ram_sfc_6 = []
    cpu_sfc_6 = []
    bandwidth_sfc_6 = []

    with open(file_name, newline='') as csvfile:
        spamreader = csv.reader(csvfile, delimiter=',', quotechar='|')
        for row in spamreader:
            if "node2" in row[5]:
                cpu_sfc_6.append(float(row[1]))
                ram_sfc_6.append(float(row[2]))
        
        average_cpu_sfc_6.append(np.mean(cpu_sfc_6))
        average_ram_sfc_6.append(np.mean(ram_sfc_6))

ram_sfc_6_mean = np.mean(average_ram_sfc_6)
cpu_sfc_6_mean = np.mean(average_cpu_sfc_6)

ram_sfc_6_std = np.std(average_ram_sfc_6)
cpu_sfc_6_std = np.std(average_cpu_sfc_6)

# %%
# CPU in edge
data = [cpu_sfc_1_mean, cpu_sfc_2_mean, cpu_sfc_3_mean, cpu_sfc_4_mean, cpu_sfc_5_mean, cpu_sfc_6_mean]
error = [cpu_sfc_1_std, cpu_sfc_2_std, cpu_sfc_3_std, cpu_sfc_4_std, cpu_sfc_5_std, cpu_sfc_6_std]
state = ["match av","background blur", "face detection", "transcoder","face recognition", "noise filter"]
fig1, ax1 = plot.subplots()
x_pos = x_pos = np.arange(len(state))
ax1.bar(x_pos, data, yerr=error, align='center',
        alpha=0.9, ecolor='black', capsize=10)
ax1.set_title('CPU in cloud node(480p)')
ax1.set_ylabel("%")
plot.xticks(rotation = 15)
ax1.set_xticks(x_pos)
ax1.set_xticklabels(state)
for i, v in enumerate(data):
    if v > 2:
        ax1.text(i, v/2-(v/2)*0.05, str(round(v,2)), ha='center')
    else:    
        ax1.text(i, v+0.5, str(round(v,2)), ha='center')
plot.show()

# %%
# RAM in edge
data = [ram_sfc_1_mean, ram_sfc_2_mean, ram_sfc_3_mean, ram_sfc_4_mean, ram_sfc_5_mean, ram_sfc_6_mean]
error = [ram_sfc_1_std, ram_sfc_2_std, ram_sfc_3_std, ram_sfc_4_std, ram_sfc_5_std, ram_sfc_6_std]
state = ["match av","background blur", "face detection", "transcoder","face recognition", "noise filter"]
fig1, ax1 = plot.subplots()
x_pos = x_pos = np.arange(len(state))
ax1.bar(x_pos, data, yerr=error, align='center',
        alpha=0.9, ecolor='black', capsize=10)
ax1.set_title('RAM in cloud node(480p)')
ax1.set_ylabel("%")
plot.xticks(rotation = 15)
ax1.set_xticks(x_pos)
ax1.set_xticklabels(state)
for i, v in enumerate(data):
    if v > 2:
        ax1.text(i, v/2-(v/2)*0.05, str(round(v,2)), ha='center')
    else:    
        ax1.text(i, v+0.5, str(round(v,2)), ha='center')
plot.show()

# %%
average_fps_face_detection = []
average_fps_face_recognition = []
average_fps_background_blur = []

# %%
for i in range(0,1):
    file_name = "fps_prom_sfc_3_480_repeat_time_{}.csv".format(i)
    
    fps_face_detection = []

    with open(file_name, newline='') as csvfile:
        spamreader = csv.reader(csvfile, delimiter=',', quotechar='|')
        for row in spamreader:
            fps_face_detection.append(float(row[0]))
        
        average_fps_face_detection.append(np.mean(fps_face_detection))

fps_face_detection_mean = np.mean(average_fps_face_detection)

fps_face_detection_std = np.std(average_fps_face_detection)

# %%
for i in range(0,1):
    file_name = "fps_prom_sfc_2_480_repeat_time_{}.csv".format(i)
    
    fps_background_blur = []

    with open(file_name, newline='') as csvfile:
        spamreader = csv.reader(csvfile, delimiter=',', quotechar='|')
        for row in spamreader:
            fps_background_blur.append(float(row[0]))
        
        average_fps_background_blur.append(np.mean(fps_background_blur))

fps_background_blur_mean = np.mean(average_fps_background_blur)

fps_background_blur_std = np.std(average_fps_background_blur)

# %%
for i in range(0,1):
    file_name = "fps_prom_sfc_5_480_repeat_time_{}.csv".format(i)
    
    fps_face_recognition = []

    with open(file_name, newline='') as csvfile:
        spamreader = csv.reader(csvfile, delimiter=',', quotechar='|')
        for row in spamreader:
            if float(row[0]) <= 40:
                fps_face_recognition.append(float(row[0]))
        
        average_fps_face_recognition.append(np.mean(fps_face_recognition))

fps_face_recognition_mean = np.mean(average_fps_face_recognition)

fps_face_recognition_std = np.std(average_fps_face_recognition)

# %%
data = [fps_face_detection_mean, fps_background_blur_mean, fps_face_recognition_mean]
error = [fps_face_detection_std, fps_background_blur_std, fps_face_recognition_std]
state = ["face detection","background blur","face recognition"]
fig1, ax1 = plot.subplots()
x_pos = x_pos = np.arange(len(state))
ax1.bar(x_pos, data, yerr=error, align='center',
        alpha=0.9, ecolor='black', capsize=10)
ax1.set_title('FPS(480p) in cloud')
ax1.set_ylabel("%")
plot.xticks(rotation = 15)
ax1.set_xticks(x_pos)
ax1.set_xticklabels(state)
for i, v in enumerate(data):
    if v > 2:
        ax1.text(i, v/2-(v/2)*0.05, str(round(v,2)), ha='center')
    else:    
        ax1.text(i, v+0.5, str(round(v,2)), ha='center')
plot.show()
